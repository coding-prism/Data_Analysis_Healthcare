# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew

# %%
data=pd.read_csv('heart.csv')
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
data.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
data.size
# Out:
# 4242

# %%
data.shape
# Out:
# (303, 14)

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# Statistical Analysis

# %%
data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %% [markdown]
# Conclusion :

# %% [markdown]
# 1. Each column contains 303 values

# %% [markdown]
# 2. Mean value id identified for each column

# %% [markdown]
# 3. The std is standard deviation if std is close to mean  indicates that the data point have relationship, whereas a larger std indicates data points are spread further away from the mean.A low std indicates that the data points are close to the mean while a high SD indicates that the data are spread out over a large range of values.

# %% [markdown]
# 4. The minimum value of data point in each column.

# %% [markdown]
# 5. Maximum value of data point in each coloumn

# %% [markdown]
# 6. 25%,50%,and 75% of data

# %% [markdown]
# Calculate the skewness of data

# %% [markdown]
# 1. skewness=0 then normally distributed
# 2. skewness<0 then more part of data in the left tail of the distribution
# 3. skewness>0 then more part of data in the right tail of the distribution

# %%
print(skew(data,axis=0,bias=True))
# Out:
# [-0.20145969 -0.78741229  0.4823294   0.71023006  1.13773262  1.97680346
#   0.16171657 -0.53474554  0.73885058  1.26342552 -0.50579573  1.30392596
#  -0.47435893 -0.17892962]

# %% [markdown]
# Data Visualisation

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
for i in data.columns:
    sns.distplot(data[i])
    plt.show()

# %%
data.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exang     0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slope    -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# ca        0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thal      0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %%
pic=plt.figure(figsize=(14,7),dpi=100)
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(data=data,vars=['age','chol','trestbps','sex'],hue='target')

# %% [markdown]
# Analysis based on cholesterol level,age and heart disease

# %%
# Relationship between age and heart disease
sns.catplot(x='target',y='age',kind='boxen',data=data)

# %% [markdown]
# Conclusion: The dataset says the most heart disease rate in between 45 and 60

# %%
sns.catplot(x='target',y='chol',kind='boxen',data=data)

# %% [markdown]
# Conclusion:The dataset says that most of the heart disease rate is increased on the cholestrol level of 200 to 300

# %%
sns.relplot(x='chol',y='age',hue='target',data=data)

# %% [markdown]
# Analysis based on Resting blood pressure,age and heart disease

# %%
sns.catplot(x='target',y='trestbps',kind='boxen',data=data)

# %%
sns.relplot(x='trestbps',y='age',hue='target',data=data)

# %% [markdown]
# Conclusion: A normal blood pressure level id less than120/180 mmHg.
# The resting blood pressure varies from 120 to 140 range andhaving age between 40 to 60

# %% [markdown]
# Analysis based on maximum heart rate archived age and heart rate

# %%
sns.relplot(x='thalach',y='age',hue='target',data=data)

# %%
sns.catplot(x='target',y='thalach',kind='bar',data=data)

# %% [markdown]
# Conclusion: You can estimate your maximum heart rate based on your age.
# To estimate your maximum age-related heart rate, subtract your age from 220.
# For example, for a 50-year-old person, the estimated maximum age-related heart rate would be calculated as 220 – 50 years = 170 beats per minute (bpm).

# %% [markdown]
# In our dataset maximum heart rate in between 160 to 220 and age 40 to 70 range

# %% [markdown]
# 1. If the age 40, 220-40-180 is the maximum heart rate based calculation, the dataset says that,person having 30 to 40 range of age having heart rate of 200 beats per minite.

# %%
Conclusion:The main factors that increases the heart disease is blood pressure, cholestrol and heart rate.
